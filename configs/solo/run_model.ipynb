# %%
from omegaconf import OmegaConf
import numpy as np
# ---------------------------------------------------------------------------- #
# Local variables and metadata
# ---------------------------------------------------------------------------- #
# for lsst_data of 3822 tract
# epoch=448 #(TRAINING NUM OF IMAGES / BATCH SIZE 280/4 diff img set - 2351/4 = 588, same size img set - 2264/4=566, 1792/4 2298/4 )
epoch= 582 # 2331/4 # total batch size spread across multiple GPUs
bs=4 # 1 or 2 times the number of gpus batch size and make sure it's divisible by the number of GPUs
# change until memory error
metadata = OmegaConf.create() 
metadata.classes = ["galaxy", "star"]

numclasses = len(metadata.classes)

# ---------------------------------------------------------------------------- #
# Standard config (this has always been the LazyConfig/.py-style config)
# ---------------------------------------------------------------------------- #
# Get values from templates
# from ..COCO.cascade_mask_rcnn_swin_b_in21k_50ep import dataloader, model, train, lr_multiplier, optimizer
import deepdisc.model.loaders as loaders
from deepdisc.data_format.augment_image import dc2_train_augs, dc2_train_augs_full, roman_train_augs
from deepdisc.data_format.image_readers import RomanImageReader
# Out:
# /u/yse2/.local/lib/python3.9/site-packages/detectron2/model_zoo/model_zoo.py:4: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[6], line 22
#      16 # ---------------------------------------------------------------------------- #
#      17 # Standard config (this has always been the LazyConfig/.py-style config)
#      18 # ---------------------------------------------------------------------------- #
#      19 # Get values from templates
#      20 # from ..COCO.cascade_mask_rcnn_swin_b_in21k_50ep import dataloader, model, train, lr_multiplier, optimizer
#      21 import deepdisc.model.loaders as loaders
# ---> 22 from deepdisc.data_format.augment_image import dc2_train_augs, dc2_train_augs_full, roman_train_augs
#      23 from deepdisc.data_format.image_readers import RomanImageReader
#
# ImportError: cannot import name 'dc2_train_augs_full' from 'deepdisc.data_format.augment_image' (/u/yse2/deepdisc/src/deepdisc/data_format/augment_image.py)

# %%
# !python deepdisc/configs/solo/swin_lsst.py
# Out:
# Traceback (most recent call last):
#   File "/u/yse2/deepdisc/configs/solo/swin_lsst.py", line 24, in <module>
#     from ..COCO.cascade_mask_rcnn_swin_b_in21k_50ep import dataloader, model, train, lr_multiplier, optimizer
# ImportError: attempted relative import with no known parent package

# %%
# !pwd
# Out:
# /u/yse2
